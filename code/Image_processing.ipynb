# %%
from Analysis import Image, Timeseries

# %matplotlib inline

# %%
Image.batch(folder_path="../data/Example_data/Image")
# Out:
# WORKING ON FILE: 50fM.tif
#   ---LOADING IMAGES---
#           done
# no field flatness correction applied
#    ---THRESHOLDING---
#            100%
# ---IMAGE REGISTRATION---
#            100%
#   ---DATA EXTRACTION---
#            100%
# Wells Tracked: 14863

# %%
Timeseries.batch(experiment_path="../data/Example_data/Image")
# Out:
# ../data/Example_data/Image\Results_50fM
#
#
#          Unnamed: 0  frame          mean  label            y            x    UID
# 0                 0      1   7044.453333      1   216.586667   242.786667      1
# 14863             0      2   7041.370456      1   216.586667   242.786667      1
# 29726             0      3   6987.759271      1   216.586667   242.786667      1
# 44589             0      4   6991.360058      1   216.586667   242.786667      1
# 59452             0      5   7007.048206      1   216.586667   242.786667      1
# ...             ...    ...           ...    ...          ...          ...    ...
# 1070135       14862     72  10662.418558  14863  1766.236364  1041.327273  14863
# 1084998       14862     73  10670.582550  14863  1766.236364  1041.327273  14863
# 1099861       14862     74  10717.843262  14863  1766.236364  1041.327273  14863
# 1114724       14862     75  10771.686946  14863  1766.236364  1041.327273  14863
# ...
